#   inflating: DIP/Real/204.jpg
#   inflating: DIP/Real/205.jpg
#   inflating: DIP/Real/206.jpg
#   inflating: DIP/Real/207.jpg
#   inflating: DIP/Real/208.jpg
#   inflating: DIP/Real/209.jpg
#   inflating: DIP/Real/21.jpg
#   inflating: DIP/Real/210.jpg
#   inflating: DIP/Real/211.jpg
#   inflating: DIP/Real/212.jpg
#   inflating: DIP/Real/213.jpg
#   inflating: DIP/Real/214.jpg
#   inflating: DIP/Real/215.jpg
#   inflating: DIP/Real/216.jpg
#   inflating: DIP/Real/217.jpg
#   inflating: DIP/Real/218.jpg
#   inflating: DIP/Real/219.jpg
#   inflating: DIP/Real/22.jpg
#   inflating: DIP/Real/220.jpg
#   inflating: DIP/Real/221.jpg
#   inflating: DIP/Real/222.jpg
#   inflating: DIP/Real/223.jpg
#   inflating: DIP/Real/224.jpg
#   inflating: DIP/Real/225.jpg
#   inflating: DIP/Real/226.jpg
#   inflating: DIP/Real/227.jpg
#   inflating: DIP/Real/228.jpg
#   inflating: DIP/Real/229.jpg
#   inflating: DIP/Real/23.jpg
#   inflating: DIP/Real/230.jpg
#   inflating: DIP/Real/231.jpg
#   inflating: DIP/Real/232.jpg
#   inflating: DIP/Real/233.jpg
#   inflating: DIP/Real/234.jpg
#   inflating: DIP/Real/235.jpg
#   inflating: DIP/Real/236.jpg
#   inflating: DIP/Real/237.jpg
#   inflating: DIP/Real/238.jpg
#   inflating: DIP/Real/239.jpg
#   inflating: DIP/Real/24.jpg
#   inflating: DIP/Real/240.jpg
#   inflating: DIP/Real/241.jpg
#   inflating: DIP/Real/242.jpg
#   inflating: DIP/Real/243.jpg
#   inflating: DIP/Real/244.jpg
#   inflating: DIP/Real/245.jpg
#   inflating: DIP/Real/246.jpg
#   inflating: DIP/Real/247.jpg
#   inflating: DIP/Real/248.jpg
#   inflating: DIP/Real/249.jpg
#   inflating: DIP/Real/25.jpg
#   inflating: DIP/Real/250.jpg
#   inflating: DIP/Real/251.jpg
#   inflating: DIP/Real/252.jpg
#   inflating: DIP/Real/253.jpg
#   inflating: DIP/Real/254.jpg
#   inflating: DIP/Real/255.jpg
#   inflating: DIP/Real/256.jpg
#   inflating: DIP/Real/257.jpg
#   inflating: DIP/Real/258.jpg
#   inflating: DIP/Real/259.jpg
#   inflating: DIP/Real/26.jpg
#   inflating: DIP/Real/260.jpg
#   inflating: DIP/Real/261.jpg
#   inflating: DIP/Real/262.jpg
#   inflating: DIP/Real/263.jpg
#   inflating: DIP/Real/264.jpg
#   inflating: DIP/Real/265.jpg
#   inflating: DIP/Real/266.jpg
#   inflating: DIP/Real/267.jpg
#   inflating: DIP/Real/268.jpg
#   inflating: DIP/Real/269.jpg
#   inflating: DIP/Real/27.jpg
#   inflating: DIP/Real/270.jpg
#   inflating: DIP/Real/271.jpg
#   inflating: DIP/Real/272.jpg
#   inflating: DIP/Real/273.jpg
#   inflating: DIP/Real/274.jpg
#   inflating: DIP/Real/275.jpg
#   inflating: DIP/Real/276.jpg
#   inflating: DIP/Real/277.jpg
#   inflating: DIP/Real/278.jpg
#   inflating: DIP/Real/279.jpg
#   inflating: DIP/Real/28.jpg
#   inflating: DIP/Real/280.jpg
#   inflating: DIP/Real/281.jpg
#   inflating: DIP/Real/282.jpg
#   inflating: DIP/Real/283.jpg
#   inflating: DIP/Real/284.jpg
#   inflating: DIP/Real/285.jpg
#   inflating: DIP/Real/286.jpg
#   inflating: DIP/Real/287.jpg
#   inflating: DIP/Real/288.jpg
#   inflating: DIP/Real/289.jpg
#   inflating: DIP/Real/29.jpg
#   inflating: DIP/Real/290.jpg
#   inflating: DIP/Real/291.jpg
#   inflating: DIP/Real/292.jpg
#   inflating: DIP/Real/293.jpg
#   inflating: DIP/Real/294.jpg
#   inflating: DIP/Real/295.jpg
#   inflating: DIP/Real/296.jpg
#   inflating: DIP/Real/297.jpg
#   inflating: DIP/Real/298.jpg
#   inflating: DIP/Real/299.jpg
#   inflating: DIP/Real/3.jpg
#   inflating: DIP/Real/30.jpg
#   inflating: DIP/Real/300.jpg
#   inflating: DIP/Real/301.jpg
#   inflating: DIP/Real/302.jpg
#   inflating: DIP/Real/303.jpg
#   inflating: DIP/Real/304.jpg
#   inflating: DIP/Real/305.jpg
#   inflating: DIP/Real/306.jpg
#   inflating: DIP/Real/307.jpg
#   inflating: DIP/Real/308.jpg
#   inflating: DIP/Real/309.jpg
#   inflating: DIP/Real/31.jpg
#   inflating: DIP/Real/310.jpg
#   inflating: DIP/Real/311.jpg
#   inflating: DIP/Real/312.jpg
#   inflating: DIP/Real/313.jpg
#   inflating: DIP/Real/314.jpg
#   inflating: DIP/Real/315.jpg
#   inflating: DIP/Real/316.jpg
#   inflating: DIP/Real/317.jpg
#   inflating: DIP/Real/318.jpg
#   inflating: DIP/Real/319.jpg
#   inflating: DIP/Real/32.jpg
#   inflating: DIP/Real/320.jpg
#   inflating: DIP/Real/321.jpg
#   inflating: DIP/Real/322.jpg
#   inflating: DIP/Real/323.jpg
#   inflating: DIP/Real/324.jpg
#   inflating: DIP/Real/325.jpg
#   inflating: DIP/Real/326.jpg
#   inflating: DIP/Real/327.jpg
#   inflating: DIP/Real/328.jpg
#   inflating: DIP/Real/329.jpg
#   inflating: DIP/Real/33.jpg
#   inflating: DIP/Real/330.jpg
#   inflating: DIP/Real/331.jpg
#   inflating: DIP/Real/332.jpg
#   inflating: DIP/Real/333.jpg
#   inflating: DIP/Real/334.jpg
#   inflating: DIP/Real/335.jpg
#   inflating: DIP/Real/336.jpg
#   inflating: DIP/Real/337.jpg
#   inflating: DIP/Real/338.jpg
#   inflating: DIP/Real/339.jpg
#   inflating: DIP/Real/34.jpg
#   inflating: DIP/Real/340.jpg
#   inflating: DIP/Real/341.jpg
#   inflating: DIP/Real/342.jpg
#   inflating: DIP/Real/343.jpg
#   inflating: DIP/Real/344.jpg
#   inflating: DIP/Real/345.jpg
#   inflating: DIP/Real/346.jpg
#   inflating: DIP/Real/347.jpg
#   inflating: DIP/Real/348.jpg
#   inflating: DIP/Real/349.jpg
#   inflating: DIP/Real/35.jpg
#   inflating: DIP/Real/350.jpg
#   inflating: DIP/Real/351.jpg
#   inflating: DIP/Real/352.jpg
#   inflating: DIP/Real/353.jpg
#   inflating: DIP/Real/354.jpg
#   inflating: DIP/Real/355.jpg
#   inflating: DIP/Real/356.jpg
#   inflating: DIP/Real/357.jpg
#   inflating: DIP/Real/358.jpg
#   inflating: DIP/Real/359.jpg
#   inflating: DIP/Real/36.jpg
#   inflating: DIP/Real/360.jpg
#   inflating: DIP/Real/361.jpg
#   inflating: DIP/Real/362.jpg
#   inflating: DIP/Real/363.jpg
#   inflating: DIP/Real/364.jpg
#   inflating: DIP/Real/365.jpg
#   inflating: DIP/Real/366.jpg
#   inflating: DIP/Real/367.jpg
#   inflating: DIP/Real/368.jpg
#   inflating: DIP/Real/369.jpg
#   inflating: DIP/Real/37.jpg
#   inflating: DIP/Real/370.jpg
#   inflating: DIP/Real/371.jpg
#   inflating: DIP/Real/372.jpg
#   inflating: DIP/Real/373.jpg
#   inflating: DIP/Real/374.jpg
#   inflating: DIP/Real/375.jpg
#   inflating: DIP/Real/376.jpg
#   inflating: DIP/Real/377.jpg
#   inflating: DIP/Real/378.jpg
#   inflating: DIP/Real/379.jpg
#   inflating: DIP/Real/38.jpg
#   inflating: DIP/Real/380.jpg
#   inflating: DIP/Real/381.jpg
#   inflating: DIP/Real/382.jpg
#   inflating: DIP/Real/383.jpg
#   inflating: DIP/Real/384.jpg
#   inflating: DIP/Real/385.jpg
#   inflating: DIP/Real/386.jpg
#   inflating: DIP/Real/387.jpg
#   inflating: DIP/Real/388.jpg
#   inflating: DIP/Real/389.jpg
#   inflating: DIP/Real/39.jpg
#   inflating: DIP/Real/390.jpg
#   inflating: DIP/Real/391.jpg
#   inflating: DIP/Real/392.jpg
#   inflating: DIP/Real/393.jpg
#   inflating: DIP/Real/394.jpg
#   inflating: DIP/Real/395.jpg
#   inflating: DIP/Real/396.jpg
#   inflating: DIP/Real/397.jpg
#   inflating: DIP/Real/398.jpg
#   inflating: DIP/Real/399.jpg
#   inflating: DIP/Real/4.jpg
#   inflating: DIP/Real/40.jpg
#   inflating: DIP/Real/400.jpg
#   inflating: DIP/Real/401.jpg
#   inflating: DIP/Real/402.jpg
#   inflating: DIP/Real/403.jpg
#   inflating: DIP/Real/404.jpg
#   inflating: DIP/Real/405.jpg
#   inflating: DIP/Real/406.jpg
#   inflating: DIP/Real/407.jpg
#   inflating: DIP/Real/408.jpg
#   inflating: DIP/Real/409.jpg
#   inflating: DIP/Real/41.jpg
#   inflating: DIP/Real/410.jpg
#   inflating: DIP/Real/411.jpg
#   inflating: DIP/Real/412.jpg
#   inflating: DIP/Real/413.jpg
#   inflating: DIP/Real/414.jpg
#   inflating: DIP/Real/415.jpg
#   inflating: DIP/Real/416.jpg
#   inflating: DIP/Real/417.jpg
#   inflating: DIP/Real/418.jpg
#   inflating: DIP/Real/419.jpg
#   inflating: DIP/Real/42.jpg
#   inflating: DIP/Real/420.jpg
#   inflating: DIP/Real/421.jpg
#   inflating: DIP/Real/422.jpg
#   inflating: DIP/Real/423.jpg
#   inflating: DIP/Real/424.jpg
#   inflating: DIP/Real/425.jpg
#   inflating: DIP/Real/426.jpg
#   inflating: DIP/Real/427.jpg
#   inflating: DIP/Real/428.jpg
#   inflating: DIP/Real/429.jpg
#   inflating: DIP/Real/43.jpg
#   inflating: DIP/Real/430.jpg
#   inflating: DIP/Real/431.jpg
#   inflating: DIP/Real/432.jpg
#   inflating: DIP/Real/433.jpg
#   inflating: DIP/Real/434.jpg
#   inflating: DIP/Real/435.jpg
#   inflating: DIP/Real/436.jpg
#   inflating: DIP/Real/437.jpg
#   inflating: DIP/Real/438.jpg
#   inflating: DIP/Real/439.jpg
#   inflating: DIP/Real/44.jpg
#   inflating: DIP/Real/440.jpg
#   inflating: DIP/Real/441.jpg
#   inflating: DIP/Real/442.jpg
#   inflating: DIP/Real/443.jpg
#   inflating: DIP/Real/444.jpg
#   inflating: DIP/Real/445.jpg
#   inflating: DIP/Real/446.jpg
#   inflating: DIP/Real/447.jpg
#   inflating: DIP/Real/448.jpg
#   inflating: DIP/Real/449.jpg
#   inflating: DIP/Real/45.jpg
#   inflating: DIP/Real/450.jpg
#   inflating: DIP/Real/451.jpg
#   inflating: DIP/Real/452.jpg
#   inflating: DIP/Real/453.jpg
#   inflating: DIP/Real/454.jpg
#   inflating: DIP/Real/455.jpg
#   inflating: DIP/Real/456.jpg
#   inflating: DIP/Real/457.jpg
#   inflating: DIP/Real/458.jpg
#   inflating: DIP/Real/459.jpg
#   inflating: DIP/Real/46.jpg
#   inflating: DIP/Real/460.jpg
#   inflating: DIP/Real/461.jpg
#   inflating: DIP/Real/462.jpg
#   inflating: DIP/Real/463.jpg
#   inflating: DIP/Real/464.jpg
#   inflating: DIP/Real/465.jpg
#   inflating: DIP/Real/466.jpg
#   inflating: DIP/Real/467.jpg
#   inflating: DIP/Real/468.jpg
#   inflating: DIP/Real/469.jpg
#   inflating: DIP/Real/47.jpg
#   inflating: DIP/Real/470.jpg
#   inflating: DIP/Real/471.jpg
#   inflating: DIP/Real/472.jpg
#   inflating: DIP/Real/473.jpg
#   inflating: DIP/Real/474.jpg
#   inflating: DIP/Real/475.jpg
#   inflating: DIP/Real/476.jpg
#   inflating: DIP/Real/477.jpg
#   inflating: DIP/Real/478.jpg
#   inflating: DIP/Real/479.jpg
#   inflating: DIP/Real/48.jpg
#   inflating: DIP/Real/480.jpg
#   inflating: DIP/Real/481.jpg
#   inflating: DIP/Real/482.jpg
#   inflating: DIP/Real/483.jpg
#   inflating: DIP/Real/484.jpg
#   inflating: DIP/Real/485.jpg
#   inflating: DIP/Real/486.jpg
#   inflating: DIP/Real/487.jpg
#   inflating: DIP/Real/488.jpg
#   inflating: DIP/Real/489.jpg
#   inflating: DIP/Real/49.jpg
#   inflating: DIP/Real/490.jpg
#   inflating: DIP/Real/491.jpg
#   inflating: DIP/Real/492.jpg
#   inflating: DIP/Real/493.jpg
#   inflating: DIP/Real/494.jpg
#   inflating: DIP/Real/495.jpg
#   inflating: DIP/Real/496.jpg
#   inflating: DIP/Real/497.jpg
#   inflating: DIP/Real/498.jpg
#   inflating: DIP/Real/499.jpg
#   inflating: DIP/Real/5.jpg
#   inflating: DIP/Real/50.jpg
#   inflating: DIP/Real/500.jpg
#   inflating: DIP/Real/51.jpg
#   inflating: DIP/Real/52.jpg
#   inflating: DIP/Real/53.jpg
#   inflating: DIP/Real/54.jpg
#   inflating: DIP/Real/55.jpg
#   inflating: DIP/Real/56.jpg
#   inflating: DIP/Real/57.jpg
#   inflating: DIP/Real/58.jpg
#   inflating: DIP/Real/59.jpg
#   inflating: DIP/Real/6.jpg
#   inflating: DIP/Real/60.jpg
#   inflating: DIP/Real/61.jpg
#   inflating: DIP/Real/62.jpg
#   inflating: DIP/Real/63.jpg
#   inflating: DIP/Real/64.jpg
#   inflating: DIP/Real/65.jpg
#   inflating: DIP/Real/66.jpg
#   inflating: DIP/Real/67.jpg
#   inflating: DIP/Real/68.jpg
#   inflating: DIP/Real/69.jpg
#   inflating: DIP/Real/7.jpg
#   inflating: DIP/Real/70.jpg
#   inflating: DIP/Real/71.jpg
#   inflating: DIP/Real/72.jpg
#   inflating: DIP/Real/73.jpg
#   inflating: DIP/Real/74.jpg
#   inflating: DIP/Real/75.jpg
#   inflating: DIP/Real/76.jpg
#   inflating: DIP/Real/77.jpg
#   inflating: DIP/Real/78.jpg
#   inflating: DIP/Real/79.jpg
#   inflating: DIP/Real/8.jpg
#   inflating: DIP/Real/80.jpg
#   inflating: DIP/Real/81.jpg
#   inflating: DIP/Real/82.jpg
#   inflating: DIP/Real/83.jpg
#   inflating: DIP/Real/84.jpg
#   inflating: DIP/Real/85.jpg
#   inflating: DIP/Real/86.jpg
#   inflating: DIP/Real/87.jpg
#   inflating: DIP/Real/88.jpg
#   inflating: DIP/Real/89.jpg
#   inflating: DIP/Real/9.jpg
#   inflating: DIP/Real/90.jpg
#   inflating: DIP/Real/91.jpg
#   inflating: DIP/Real/92.jpg
#   inflating: DIP/Real/93.jpg
#   inflating: DIP/Real/94.jpg
#   inflating: DIP/Real/95.jpg
#   inflating: DIP/Real/96.jpg
#   inflating: DIP/Real/97.jpg
#   inflating: DIP/Real/98.jpg
#   inflating: DIP/Real/99.jpg

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
import radialProfile

epsilon = 1e-8
filename = '/content/DIP/Fake/2.jpg'
#reading image as greyscale image
img = cv2.imread(filename,0)
#reading original image
img_color = mpimg.imread(filename)
# Calculate FFT
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
fshift += epsilon
magnitude_spectrum = 20*np.log(np.abs(fshift))
# Calculate the azimuthally averaged 1D power spectrum
psd1D = radialProfile.azimuthalAverage(magnitude_spectrum)

#Visualization
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(121)
plt.axis('off')
ax2 = fig.add_subplot(122)
ax.set_title('input image - Fake',size=15)
ax2.set_title('1D Power Spectrum',size=15)
plt.xlabel('Spatial Frequency', fontsize=20)
plt.ylabel('Power Spectrum', fontsize=20)
ax.imshow(img_color)
ax2.plot(psd1D)
plt.show()

filename = '/content/DIP/Real/2.jpg'
#reading image as greyscale image
img = cv2.imread(filename,0)
#reading original image
img_color = mpimg.imread(filename)
# Calculate FFT
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
fshift += epsilon
magnitude_spectrum = 20*np.log(np.abs(fshift))
# Calculate the azimuthally averaged 1D power spectrum
psd1D = radialProfile.azimuthalAverage(magnitude_spectrum)

#Visualization
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(121)
plt.axis('off')
ax2 = fig.add_subplot(122)
ax.set_title('input image - Real',size=15)
ax2.set_title('1D Power Spectrum',size=15)
plt.xlabel('Spatial Frequency', fontsize=20)
plt.ylabel('Power Spectrum', fontsize=20)
ax.imshow(img_color)
ax2.plot(psd1D)
plt.show()

# %% [markdown]
# # Visualization 1d Power Spectrum statistics

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import radialProfile
import glob

y = []
error = []

path = ['/content/DIP/Fake/', '/content/DIP/Real/']

for z in range(2):
    # number of images from each dataset
    num_images = 10
    epsilon = 1e-8
    cont = 0
    psd1D_org = np.zeros((num_images,722))
    psd1D_org_mean = np.zeros(722)
    psd1D_org_std = np.zeros(722)
    

    for filename in glob.glob(path[z]+"*.jpg"):   

        img = cv2.imread(filename,0)
        # Calculate FFT
        f = np.fft.fft2(img)
        fshift = np.fft.fftshift(f)
        fshift += epsilon
        magnitude_spectrum = 20*np.log(np.abs(fshift))
        # Calculate the azimuthally averaged 1D power spectrum
        psd1D = radialProfile.azimuthalAverage(magnitude_spectrum)

        if cont == num_images:
            break

        psd1D_org[cont,:] = psd1D
        cont +=1

    for x in range(722):
        psd1D_org_mean[x] = np.mean(psd1D_org[:,x])
        psd1D_org_std[x]= np.std(psd1D_org[:,x])

    x = np.arange(0, 722, 1)
    y.append(psd1D_org_mean)
    error.append(psd1D_org_std)

fig, ax = plt.subplots(figsize=(15, 9))
ax.plot(x, y[0], alpha=0.5, color='red', label='Fake', linewidth =2.0)
ax.fill_between(x, y[0] - error[0], y[0] + error[0], color='red', alpha=0.2)

ax.plot(x, y[1], alpha=0.5, color='blue', label='Real', linewidth = 2.0)
ax.fill_between(x, y[1] - error[1], y[1] + error[1], color='blue', alpha=0.2)


ax.set_title('Satistics 1D Power Spectrum',size=20)
plt.xlabel('Spatial Frequency', fontsize=20)
plt.ylabel('Power Spectrum', fontsize=20)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
ax.legend(loc='best', prop={'size': 20})
plt.show()

# %% [markdown]
# # Visualization High-Frequency Components

# %%
def create_circular_mask(h, w, center=None, radius=None):

    if center is None: # use the middle of the image
        center = [int(w/2), int(h/2)]
    if radius is None: # use the smallest distance between the center and image walls
        radius = min(center[0], center[1], w-center[0], h-center[1])

    Y, X = np.ogrid[:h, :w]
    dist_from_center = np.sqrt((X - center[0])**2 + (Y-center[1])**2)

    mask = dist_from_center <= radius

    return mask

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
import radialProfile
import glob

epsilon = 1e-8
filename = '/content/real.jpg'

mask = create_circular_mask(1024,1024,radius=500)
mask = np.invert(mask)
inv = np.zeros([1024,1024,3])
img_color =[]

# Read image and split color-channels
img_color = mpimg.imread(filename)
img_r = img_color[:,:,0]
img_b = img_color[:,:,1]
img_g = img_color[:,:,2]

# Calculate FFT and appply mask for each channel
f_r = np.fft.fft2(img_r)
fshift_r = np.fft.fftshift(f_r)       
fshift_r = fshift_r*mask       
f_ishift_r = np.fft.ifftshift(fshift_r)
img_back_r = np.fft.ifft2(f_ishift_r)
img_back_r = np.abs(img_back_r)

f_b = np.fft.fft2(img_b)
fshift_b = np.fft.fftshift(f_b)
fshift_b = fshift_b*mask   
f_ishift_b = np.fft.ifftshift(fshift_b)
img_back_b = np.fft.ifft2(f_ishift_b)
img_back_b = np.abs(img_back_b)

f_g = np.fft.fft2(img_g)
fshift_g = np.fft.fftshift(f_g)
fshift_g = fshift_g*mask   
f_ishift_g = np.fft.ifftshift(fshift_g)
img_back_g = np.fft.ifft2(f_ishift_g)
img_back_g = np.abs(img_back_g)

inv[:,:,0] = np.round(img_back_r)/255
inv[:,:,1] = np.round(img_back_b)/255
inv[:,:,2] = np.round(img_back_g)/255

# Visualization
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(121)
plt.axis('off')
ax2 = fig.add_subplot(122)
plt.axis('off')

# Weightning for enhance visualization
inv2 = np.copy(inv)
inv2 /= inv.max()
inv2 *= 4

ax.set_title('input image - Real',size=15)
ax.imshow(img_color)
ax2.set_title('output image (only high-freq comp.)',size=15)
ax2.imshow(inv2)
plt.show()


epsilon = 1e-8
filename = '/content/fake.jpg'

mask = create_circular_mask(1024,1024,radius=500)
mask = np.invert(mask)
inv = np.zeros([1024,1024,3])
img_color =[]

# Read image and split color-channels
img_color = mpimg.imread(filename)
img_r = img_color[:,:,0]
img_b = img_color[:,:,1]
img_g = img_color[:,:,2]

# Calculate FFT and appply mask for each channel
f_r = np.fft.fft2(img_r)
fshift_r = np.fft.fftshift(f_r)       
fshift_r = fshift_r*mask       
f_ishift_r = np.fft.ifftshift(fshift_r)
img_back_r = np.fft.ifft2(f_ishift_r)
img_back_r = np.abs(img_back_r)

f_b = np.fft.fft2(img_b)
fshift_b = np.fft.fftshift(f_b)
fshift_b = fshift_b*mask   
f_ishift_b = np.fft.ifftshift(fshift_b)
img_back_b = np.fft.ifft2(f_ishift_b)
img_back_b = np.abs(img_back_b)

f_g = np.fft.fft2(img_g)
fshift_g = np.fft.fftshift(f_g)
fshift_g = fshift_g*mask   
f_ishift_g = np.fft.ifftshift(fshift_g)
img_back_g = np.fft.ifft2(f_ishift_g)
img_back_g = np.abs(img_back_g)

inv[:,:,0] = np.round(img_back_r)/255
inv[:,:,1] = np.round(img_back_b)/255
inv[:,:,2] = np.round(img_back_g)/255

# Visualization
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(121)
plt.axis('off')
ax2 = fig.add_subplot(122)
plt.axis('off')

# Weightning for enhance visualization
inv2 = np.copy(inv)
inv2 /= inv.max()
inv2 *= 4

ax.set_title('input image -Fake',size=15)
ax.imshow(img_color)
ax2.set_title('output image (only high-freq comp.)',size=15)
ax2.imshow(inv2)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
